# %%
import sys
sys.executable
# Out:
# '/usr/local/opt/python/bin/python3.7'

# %%
import pickle
import matplotlib.pyplot as plt

# %%
n = 1000
D = 2
x_scatter = []; y_scatter = []

# pickling

for i in range(1,51):
    f = open("slurm scripts/data/06-04-20/"+str(i)+"-dim"+str(D)+"-n"+str(n)+"_plotpoints.pkl","rb")
    load = pickle.load(f)
    f.close()
    
    x_scatter.extend(load[0])
    y_scatter.extend(load[1])

plt.figure(figsize=(8,8))
axes = plt.gca()
#axes.set_xlim([0,0.15])
#axes.margins(y=0.01)

plt.scatter(x_scatter, y_scatter, s=8, c='blue')
plt.title('Signed Angle Displacement x Edge Length; n = '+str(n))
plt.xlabel('path edge length')
plt.ylabel('path edge signed angle displacement w.r.t x_goal')
#plt.savefig('sample3.png')
#plt.close()
# Out:
# Text(0, 0.5, 'path edge signed angle displacement w.r.t x_goal')

# %%
n = 10000
D = 2
x_scatter = []; y_scatter = []

# pickling

for i in range(1,51):
    f = open("slurm scripts/data/06-04-20/"+str(i)+"-dim"+str(D)+"-n"+str(n)+"_plotpoints.pkl","rb")
    load = pickle.load(f)
    f.close()
    
    x_scatter.extend(load[0])
    y_scatter.extend(load[1])

plt.figure(figsize=(8,8))
axes = plt.gca()
#axes.set_xlim([0,0.15])
#axes.margins(y=0.01)

plt.scatter(x_scatter, y_scatter, s=8, c='blue')
plt.title('Signed Angle Displacement x Edge Length; n = '+str(n))
plt.xlabel('path edge length')
plt.ylabel('path edge signed angle displacement w.r.t x_goal')
#plt.savefig('sample3.png')
#plt.close()
# Out:
# Text(0, 0.5, 'path edge signed angle displacement w.r.t x_goal')

# %%
n = 100000
D = 2
x_scatter = []; y_scatter = []

# pickling

for i in range(1,51):
    f = open("slurm scripts/data/06-04-20/n100000/"+str(i)+"-dim"+str(D)+"-n"+str(n)+"_plotpoints.pkl","rb")
    load = pickle.load(f)
    f.close()
    
    x_scatter.extend(load[0])
    y_scatter.extend(load[1])

plt.figure(figsize=(8,8))
axes = plt.gca()
#axes.set_xlim([0,0.15])
#axes.margins(y=0.01)

plt.scatter(x_scatter, y_scatter, s=8, c='blue')
plt.title('Signed Angle Displacement x Edge Length; n = '+str(n))
plt.xlabel('path edge length')
plt.ylabel('path edge signed angle displacement w.r.t x_goal')
# Out:
# Text(0, 0.5, 'path edge signed angle displacement w.r.t x_goal')
